# %% [markdown]
# # SPIB Demo 2021
# This notebook aims to serve as a simple introduction to the state predictive information bottleneck method of [Wang and Tiwary 2021](https://aip.scitation.org/doi/abs/10.1063/5.0038198). The code is implemented using Pytorch.

# %% [markdown]
# <img src="fig/Fig_alg.png">

# %% [markdown]
# <img src="fig/Fig_FW_example.png">

# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import time

plt.rcParams['figure.figsize'] = [25, 20]
np.random.seed(42)

# %%
large = 54; med = 36; small = 24
l_width = 3; m_width = 1.5; s_width = 0.7
params = {'axes.titlesize': large,
          'legend.fontsize': large,
          'legend.title_fontsize':large,
          'figure.figsize': (16, 10),
          'axes.labelsize': large,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large,
          'lines.linewidth': l_width,
          'lines.markersize': 10,
          'axes.linewidth': l_width,
          'xtick.major.size': 8,
          'ytick.major.size': 8,
          'xtick.minor.size': 4,
          'ytick.minor.size': 4,
          'xtick.major.width': m_width,
          'ytick.major.width': m_width,
          'xtick.minor.width': s_width,
          'ytick.minor.width': s_width,
          'grid.linewidth': m_width}
plt.rcParams.update(params)

# %% [markdown]
# ## Data Preparation
# The trajectory data can be generated from the molecular dynamics simulation or experiements. Here, we use a sample trajectory generated from Langevin dynamics simulation of a four-well analytical potential.

# %%
# Load trajectory data
traj_data = np.load("examples/Four_Well_beta3_gamma4_traj_data.npy")

# %% [markdown]
# ### Visualization of the trajectory

# %%
fig, ax = plt.subplots(figsize=(12,10))

t = np.arange(traj_data.shape[0])
ax.plot(t[::100],traj_data[::100,0],'x',label='x')
ax.plot(t[::100],traj_data[::100,1],'o',fillstyle='none',label='y')
ax.set_xlabel('time step')
ax.legend(fontsize=36,bbox_to_anchor=(0.99, 0.7))

# %%
# The four-well analytical potential along x
def potential_fn_FW(x):
    A=0.6
    a=80
    B=0.2
    b=80
    C=0.5
    c=40
    return 2*(x**8+A*np.exp(-a*x**2)+B*np.exp(-b*(x-0.5)**2)+C*np.exp(-c*(x+0.5)**2))+(x**2-1)**2

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots(1,2,figsize=(18,8))

beta=3
lw=8

x=np.arange(-1,1,0.01)
v=potential_fn_FW(x)
ax[0].plot(x,v,color='k',lw=lw)
ax[0].axvline(x=0,color='b',linestyle='--',lw=lw)
ax[0].axvline(x=-0.5,color='b',linestyle='--',lw=lw)
ax[0].axvline(x=0.5,color='b',linestyle='--',lw=lw)
ax[0].text(-0.75, 1.8, 'A', horizontalalignment='center',fontsize=54)
ax[0].text(-0.25, 1.8, 'B', horizontalalignment='center', fontsize=54)
ax[0].text(0.25, 1.8, 'C', horizontalalignment='center',fontsize=54)
ax[0].text(0.75, 1.8, 'D', horizontalalignment='center', fontsize=54)
ax[0].set_xlabel("x")
ax[0].set_ylabel("Potential")

ax[0].text(-0.2, 1.2, '(a)', horizontalalignment='center',
             transform=ax[0].transAxes,fontsize=54, va='top')

FW_counts,FW_xbins,FW_ybins,images = plt.hist2d(traj_data[:,0],traj_data[:,1],bins=100)
FW_counts[FW_counts==0]=FW_counts[FW_counts!=0].min()
FW_G=-np.log(FW_counts)/beta
FW_G=FW_G-np.nanmin(FW_G)

h0=ax[1].contourf(FW_G.transpose(),levels=5,extent=[FW_xbins[0],FW_xbins[-1],FW_ybins[0],FW_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,FW_G.max(),1)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label('Free Energy',fontsize=48)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax[1].set_xlabel("x")
ax[1].set_ylabel('y')


ax[1].text(-0.2, 1.3, '(b)', horizontalalignment='center',
             transform=ax[1].transAxes,fontsize=54, va='top')

plt.tight_layout(pad=0.4, w_pad=5, h_pad=3.0)

# %% [markdown]
# ### Generation of initial state labels

# %%
# discretize the system along x to 10 states as initial state labels
index=0

x_max=traj_data[:,index].max()+0.01
x_min=traj_data[:,index].min()-0.01

state_num=10
eps=1e-3

x_det=(x_max-x_min+2*eps)/state_num

init_label=np.zeros((traj_data.shape[0],state_num))

x_list=np.array([(x_min-eps+n*x_det) for n in range(state_num+1)])

for j in range(state_num):
    indices=(traj_data[:,index]>x_list[j])&(traj_data[:,index]<=x_list[j+1])
    init_label[indices,j]=1

np.save('examples/Four_Well_beta3_gamma4_init_label10.npy',init_label)

# %%
# plot the initial state labels for four well potential system
import matplotlib
from matplotlib import colors as c
data=traj_data
labels=init_label

fig0, ax0 = plt.subplots(figsize=(9,6))
hist=ax0.hist2d(data[:,0],data[:,1],bins=100)

state_num=labels.shape[1]
state_labels=np.arange(state_num)

x_max=np.max(data[:,0])
x_min=np.min(data[:,0])

eps=1e-3

x_det=(x_max-x_min+2*eps)/state_num

x_list=np.array([(x_min-eps+n*x_det) for n in range(state_num+1)])

hist_state=np.zeros([state_num]+list(hist[0].shape))

for i in range(state_num):
    hist_state[i]=ax0.hist2d(data[:,0],data[:,1],bins=[hist[1],hist[2]],weights=labels[:,i])[0]
    
init_label_map=np.argmax(hist_state,axis=0).astype(float)
init_label_map[hist[0]==0]=np.nan
plt.close(fig0)

# %%
fig, ax = plt.subplots(figsize=(9,6))

fmt = matplotlib.ticker.FuncFormatter(lambda x, pos: state_labels[x])
tickz = np.arange(0,len(state_labels))

cMap = c.ListedColormap(plt.cm.tab20.colors[0:10])
im=ax.pcolormesh(hist[1], hist[2], init_label_map.T, cmap=cMap, vmin=-0.5, vmax=len(state_labels)-0.5)
cb1 = fig.colorbar(im,ax=ax,format=fmt, ticks=tickz)

for i in range(state_num):
    ax.text((x_list[i]+x_list[i+1])/2,0,state_labels[i],horizontalalignment='center',verticalalignment='center',fontsize=32)
    
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Model
# We provide two ways to run SPIB: test_model.py and test_model_advanced.py. Here, we will only discuss the use of test_model.py. But for advanced analyses, we will strongly recommend to use test_model_advanced.py as it provides more features to help you to control the training process and tune the hyper-parameters.

# %% [markdown]
# ## Training

# %%
# %run test_model.py -dt 50 -d 1 -encoder_type Nonlinear -bs 512 -threshold 0.01 -patience 2 -refinements 8 -lr 0.001 -b 0.01 -seed 0 -label examples/Four_Well_beta3_gamma4_init_label10.npy -traj examples/Four_Well_beta3_gamma4_traj_data.npy
# Out:
# Iteration 500:	Time 4.732524 s
# Loss (train) 1.008381	KL loss (train): 2.283907
# Reconstruction loss (train) 0.985542
# Loss (test) 1.092693	KL loss (test): 2.190849
# Reconstruction loss (test) 1.070784
# tensor([0.0000, 0.2321, 0.0000, 0.0536, 0.0000, 0.0000, 0.1281, 0.0000, 0.5862,
#         0.0000])
# State population change=0.264010
# Epoch: 1
#
# Iteration 1000:	Time 9.372603 s
# Loss (train) 0.992533	KL loss (train): 2.359234
# Reconstruction loss (train) 0.968941
# Loss (test) 0.947073	KL loss (test): 2.336588
# Reconstruction loss (test) 0.923707
# tensor([0.0000, 0.2280, 0.0000, 0.0578, 0.0000, 0.0000, 0.1453, 0.0000, 0.5689,
#         0.0000])
# State population change=0.025117
# Epoch: 2
#
# Iteration 1500:	Time 13.964036 s
# Loss (train) 0.976678	KL loss (train): 2.105039
# Reconstruction loss (train) 0.955627
# Loss (test) 0.918489	KL loss (test): 1.962011
# Reconstruction loss (test) 0.898869
# tensor([0.0000, 0.2273, 0.0000, 0.0585, 0.0000, 0.0000, 0.1523, 0.0000, 0.5619,
#         0.0000])
# State population change=0.009921
# Epoch: 3
#
# Iteration 2000:	Time 18.613315 s
# Loss (train) 0.953903	KL loss (train): 2.279516
# Reconstruction loss (train) 0.931108
# Loss (test) 0.998857	KL loss (test): 2.242112
# Reconstruction loss (test) 0.976436
# tensor([0.0000, 0.2278, 0.0000, 0.0578, 0.0000, 0.0000, 0.1521, 0.0000, 0.5623,
#         0.0000])
# State population change=0.000924
# Epoch: 4
#
# Iteration 2500:	Time 23.228149 s
# Loss (train) 0.918681	KL loss (train): 2.291873
# Reconstruction loss (train) 0.895763
# Loss (test) 0.972685	KL loss (test): 2.094609
# Reconstruction loss (test) 0.951739
# tensor([0.0000, 0.2276, 0.0000, 0.0582, 0.0000, 0.0000, 0.1591, 0.0000, 0.5551,
#         0.0000])
# State population change=0.010075
# Epoch: 5
#
# Iteration 3000:	Time 28.052510 s
# Loss (train) 0.904214	KL loss (train): 2.232782
# Reconstruction loss (train) 0.881886
# Loss (test) 0.941011	KL loss (test): 2.154569
# Reconstruction loss (test) 0.919465
# tensor([0.0000, 0.2279, 0.0000, 0.0579, 0.0000, 0.0000, 0.1637, 0.0000, 0.5505,
#         0.0000])
# State population change=0.006478
# Epoch: 6
#
# Iteration 3500:	Time 32.789306 s
# Loss (train) 0.985891	KL loss (train): 2.437329
# Reconstruction loss (train) 0.961517
# Loss (test) 0.950276	KL loss (test): 2.362431
# Reconstruction loss (test) 0.926651
# tensor([0.0000, 0.2277, 0.0000, 0.0580, 0.0000, 0.0000, 0.1570, 0.0000, 0.5573,
#         0.0000])
# State population change=0.009588
# Epoch: 7
#
# Iteration 4000:	Time 37.608727 s
# Loss (train) 0.975490	KL loss (train): 2.309101
# Reconstruction loss (train) 0.952399
# Loss (test) 0.925807	KL loss (test): 2.320131
# Reconstruction loss (test) 0.902606
# tensor([0.0000, 0.2272, 0.0000, 0.0585, 0.0000, 0.0000, 0.1582, 0.0000, 0.5560,
#         0.0000])
# State population change=0.001942
# Update 1
#
# Epoch: 0
#
# Iteration 4500:	Time 42.773042 s
# Loss (train) 0.288494	KL loss (train): 2.373971
# Reconstruction loss (train) 0.264755
# Loss (test) 0.258760	KL loss (test): 2.429800
# Reconstruction loss (test) 0.234462
# tensor([0.0000, 0.2275, 0.0000, 0.0581, 0.0000, 0.0000, 0.1554, 0.0000, 0.5590,
#         0.0000])
# State population change=0.004124
# Epoch: 1
#
# Iteration 5000:	Time 47.354318 s
# Loss (train) 0.281213	KL loss (train): 2.215402
# Reconstruction loss (train) 0.259059
# Loss (test) 0.235833	KL loss (test): 2.415699
# Reconstruction loss (test) 0.211676
# tensor([0.0000, 0.2272, 0.0000, 0.0584, 0.0000, 0.0000, 0.1525, 0.0000, 0.5620,
#         0.0000])
# State population change=0.004184
# Epoch: 2
#
# Iteration 5500:	Time 52.197037 s
# Loss (train) 0.261970	KL loss (train): 2.252089
# Reconstruction loss (train) 0.239449
# Loss (test) 0.218698	KL loss (test): 2.291703
# Reconstruction loss (test) 0.195781
# tensor([0.0000, 0.2273, 0.0000, 0.0584, 0.0000, 0.0000, 0.1587, 0.0000, 0.5557,
#         0.0000])
# State population change=0.008815
# Update 2
#
# Epoch: 0
#
# Iteration 6000:	Time 57.323727 s
# Loss (train) 0.229640	KL loss (train): 2.190887
# Reconstruction loss (train) 0.207731
# Loss (test) 0.228770	KL loss (test): 2.025398
# Reconstruction loss (test) 0.208516
# tensor([0.0000, 0.2277, 0.0000, 0.0579, 0.0000, 0.0000, 0.1559, 0.0000, 0.5585,
#         0.0000])
# State population change=0.003965
# Epoch: 1
#
# Iteration 6500:	Time 61.979617 s
# Loss (train) 0.296955	KL loss (train): 2.143351
# Reconstruction loss (train) 0.275521
# Loss (test) 0.242653	KL loss (test): 1.972973
# Reconstruction loss (test) 0.222923
# tensor([0.0000, 0.2273, 0.0000, 0.0585, 0.0000, 0.0000, 0.1617, 0.0000, 0.5526,
#         0.0000])
# State population change=0.008253
# Epoch: 2
#
# Iteration 7000:	Time 66.598961 s
# Loss (train) 0.255817	KL loss (train): 1.947492
# Reconstruction loss (train) 0.236342
# Loss (test) 0.238071	KL loss (test): 2.041253
# Reconstruction loss (test) 0.217659
# tensor([0.0000, 0.2274, 0.0000, 0.0584, 0.0000, 0.0000, 0.1605, 0.0000, 0.5537,
#         0.0000])
# State population change=0.001610
# Update 3
#
# Epoch: 0
#
# Iteration 7500:	Time 72.021216 s
# Loss (train) 0.228577	KL loss (train): 1.959677
# Reconstruction loss (train) 0.208980
# Loss (test) 0.225716	KL loss (test): 1.914704
# Reconstruction loss (test) 0.206569
# tensor([0.0000, 0.2275, 0.0000, 0.0583, 0.0000, 0.0000, 0.1625, 0.0000, 0.5517,
#         0.0000])
# State population change=0.002763
# Epoch: 1
#
# Iteration 8000:	Time 76.903048 s
# Loss (train) 0.249213	KL loss (train): 2.035956
# Reconstruction loss (train) 0.228854
# Loss (test) 0.249803	KL loss (test): 1.967281
# Reconstruction loss (test) 0.230130
# tensor([0.0000, 0.2267, 0.0000, 0.0590, 0.0000, 0.0000, 0.1626, 0.0000, 0.5518,
#         0.0000])
# State population change=0.001054
# Epoch: 2
#
# Iteration 8500:	Time 81.773434 s
# Loss (train) 0.298636	KL loss (train): 1.887743
# Reconstruction loss (train) 0.279759
# Loss (test) 0.253062	KL loss (test): 1.944814
# Reconstruction loss (test) 0.233614
# tensor([0.0000, 0.2272, 0.0000, 0.0585, 0.0000, 0.0000, 0.1619, 0.0000, 0.5524,
#         0.0000])
# State population change=0.001156
# Update 4
#
# Epoch: 0
#
# Iteration 9000:	Time 87.112997 s
# Loss (train) 0.299887	KL loss (train): 1.943868
# Reconstruction loss (train) 0.280448
# Loss (test) 0.245940	KL loss (test): 2.013868
# Reconstruction loss (test) 0.225801
# Iteration 9500:	Time 91.682199 s
# Loss (train) 0.271510	KL loss (train): 1.887125
# Reconstruction loss (train) 0.252638
# Loss (test) 0.181981	KL loss (test): 1.922023
# Reconstruction loss (test) 0.162761
# tensor([0.0000, 0.2269, 0.0000, 0.0585, 0.0000, 0.0000, 0.1589, 0.0000, 0.5556,
#         0.0000])
# State population change=0.004356
# Epoch: 1
#
# Iteration 10000:	Time 96.603853 s
# Loss (train) 0.216595	KL loss (train): 1.862445
# Reconstruction loss (train) 0.197970
# Loss (test) 0.220711	KL loss (test): 1.929956
# Reconstruction loss (test) 0.201411
# tensor([0.0000, 0.2269, 0.0000, 0.0586, 0.0000, 0.0000, 0.1629, 0.0000, 0.5516,
#         0.0000])
# State population change=0.005669
# Epoch: 2
#
# Iteration 10500:	Time 101.461344 s
# Loss (train) 0.250731	KL loss (train): 1.819654
# Reconstruction loss (train) 0.232534
# Loss (test) 0.268785	KL loss (test): 1.981808
# Reconstruction loss (test) 0.248967
# tensor([0.0000, 0.2275, 0.0000, 0.0583, 0.0000, 0.0000, 0.1632, 0.0000, 0.5509,
#         0.0000])
# State population change=0.000949
# Update 5
#
# Epoch: 0
#
# Iteration 11000:	Time 106.627192 s
# Loss (train) 0.233493	KL loss (train): 2.025407
# Reconstruction loss (train) 0.213239
# Loss (test) 0.250540	KL loss (test): 2.158169
# Reconstruction loss (test) 0.228958
# tensor([0.0000, 0.2270, 0.0000, 0.0587, 0.0000, 0.0000, 0.1609, 0.0000, 0.5534,
#         0.0000])
# State population change=0.003429
# Epoch: 1
#
# Iteration 11500:	Time 111.443407 s
# Loss (train) 0.300368	KL loss (train): 1.895196
# Reconstruction loss (train) 0.281416
# Loss (test) 0.258954	KL loss (test): 1.964637
# Reconstruction loss (test) 0.239307
# tensor([0.0000, 0.2271, 0.0000, 0.0586, 0.0000, 0.0000, 0.1644, 0.0000, 0.5498,
#         0.0000])
# State population change=0.005007
# Epoch: 2
#
# Iteration 12000:	Time 116.135642 s
# Loss (train) 0.201868	KL loss (train): 2.056622
# Reconstruction loss (train) 0.181302
# Loss (test) 0.239356	KL loss (test): 2.081215
# Reconstruction loss (test) 0.218544
# tensor([0.0000, 0.2272, 0.0000, 0.0586, 0.0000, 0.0000, 0.1640, 0.0000, 0.5502,
#         0.0000])
# State population change=0.000563
# Update 6
#
# Epoch: 0
#
# Iteration 12500:	Time 121.366052 s
# Loss (train) 0.238590	KL loss (train): 1.864197
# Reconstruction loss (train) 0.219948
# Loss (test) 0.273686	KL loss (test): 1.912637
# Reconstruction loss (test) 0.254559
# tensor([0.0000, 0.2275, 0.0000, 0.0582, 0.0000, 0.0000, 0.1651, 0.0000, 0.5491,
#         0.0000])
# State population change=0.001621
# Epoch: 1
#
# Iteration 13000:	Time 126.068187 s
# Loss (train) 0.280963	KL loss (train): 1.885289
# Reconstruction loss (train) 0.262110
# Loss (test) 0.239131	KL loss (test): 1.883558
# Reconstruction loss (test) 0.220296
# tensor([0.0000, 0.2278, 0.0000, 0.0581, 0.0000, 0.0000, 0.1630, 0.0000, 0.5511,
#         0.0000])
# State population change=0.002916
# Epoch: 2
#
# Iteration 13500:	Time 130.796266 s
# Loss (train) 0.265310	KL loss (train): 1.948260
# Reconstruction loss (train) 0.245828
# Loss (test) 0.243827	KL loss (test): 1.895168
# Reconstruction loss (test) 0.224875
# tensor([0.0000, 0.2270, 0.0000, 0.0586, 0.0000, 0.0000, 0.1599, 0.0000, 0.5545,
#         0.0000])
# State population change=0.004747
# Update 7
#
# Epoch: 0
#
# Iteration 14000:	Time 136.006006 s
# Loss (train) 0.256279	KL loss (train): 1.936642
# Reconstruction loss (train) 0.236913
# Loss (test) 0.281213	KL loss (test): 1.983506
# Reconstruction loss (test) 0.261378
# tensor([0.0000, 0.2269, 0.0000, 0.0588, 0.0000, 0.0000, 0.1636, 0.0000, 0.5507,
#         0.0000])
# State population change=0.005307
# Epoch: 1
#
# Iteration 14500:	Time 140.729553 s
# Loss (train) 0.304779	KL loss (train): 2.116891
# Reconstruction loss (train) 0.283610
# Loss (test) 0.201501	KL loss (test): 1.910320
# Reconstruction loss (test) 0.182398
# tensor([0.0000, 0.2265, 0.0000, 0.0590, 0.0000, 0.0000, 0.1631, 0.0000, 0.5514,
#         0.0000])
# State population change=0.000928
# Epoch: 2
#
# Iteration 15000:	Time 145.497086 s
# Loss (train) 0.284247	KL loss (train): 2.019557
# Reconstruction loss (train) 0.264052
# Loss (test) 0.242046	KL loss (test): 1.879563
# Reconstruction loss (test) 0.223250
# tensor([0.0000, 0.2271, 0.0000, 0.0587, 0.0000, 0.0000, 0.1641, 0.0000, 0.5501,
#         0.0000])
# State population change=0.001724
# Update 8
#
# Epoch: 0
#
# Iteration 15500:	Time 150.768312 s
# Loss (train) 0.216225	KL loss (train): 1.916193
# Reconstruction loss (train) 0.197063
# Loss (test) 0.247207	KL loss (test): 2.028680
# Reconstruction loss (test) 0.226920
# tensor([0.0000, 0.2266, 0.0000, 0.0588, 0.0000, 0.0000, 0.1583, 0.0000, 0.5563,
#         0.0000])
# State population change=0.008472
# Epoch: 1
#
# Iteration 16000:	Time 155.575082 s
# Loss (train) 0.288155	KL loss (train): 2.137576
# Reconstruction loss (train) 0.266779
# Loss (test) 0.206332	KL loss (test): 2.023880
# Reconstruction loss (test) 0.186093
# tensor([0.0000, 0.2275, 0.0000, 0.0582, 0.0000, 0.0000, 0.1594, 0.0000, 0.5550,
#         0.0000])
# State population change=0.001942
# Epoch: 2
#
# Iteration 16500:	Time 160.349370 s
# Loss (train) 0.239728	KL loss (train): 2.001932
# Reconstruction loss (train) 0.219709
# Loss (test) 0.206075	KL loss (test): 2.042600
# Reconstruction loss (test) 0.185649
# tensor([0.0000, 0.2273, 0.0000, 0.0585, 0.0000, 0.0000, 0.1622, 0.0000, 0.5521,
#         0.0000])
# State population change=0.004055
# Total training time: 164.225699
# Final: 0
# Loss (train) 0.253852	KL loss (train): 1.950195
# Reconstruction loss (train) 0.234350
# Loss (test) 0.250245	KL loss (train): 1.944466
# Reconstruction loss (test) 0.230801
# dt: 50	 Beta: 0.010000	 Learning_rate: 0.001000

# %% [markdown]
# ## Result Analysis

# %%
prefix='SPIB/Unweighted_d=1_t=50_b=0.0100_learn=0.001000'
repeat='0'

# %%
# load the results
# the deterministic part of RC leanred by SPIB (the mean of output gaussian distrition of the encoder)
traj_mean_rep=np.load(prefix+"_traj0_mean_representation"+repeat+".npy")
# the final state labels leanred by SPIB
traj_labels=np.load(prefix+"_traj0_labels"+repeat+".npy")

# %%
# plot the learned state labels for four well potential system
import matplotlib
from matplotlib import colors as c
data=traj_data
labels=traj_labels
hist=plt.hist2d(data[:,0],data[:,1],bins=100)

state_num=labels.shape[1]
state_labels=np.arange(state_num)

hist_state=np.zeros([state_num]+list(hist[0].shape))

for i in range(state_num):
    hist_state[i]=plt.hist2d(data[:,0],data[:,1],bins=[hist[1],hist[2]],weights=labels[:,i])[0]
    
label_map50=np.argmax(hist_state,axis=0).astype(float)
label_map50[hist[0]==0]=np.nan

plt.close()

# %%
fig, ax = plt.subplots(figsize=(9,6))

fmt = matplotlib.ticker.FuncFormatter(lambda x, pos: state_labels[x])
tickz = np.arange(0,len(state_labels))

cMap = c.ListedColormap(plt.cm.tab20.colors[0:10])
im=ax.pcolormesh(hist[1], hist[2], label_map50.T, cmap=cMap, vmin=-0.5, vmax=len(state_labels)-0.5)
cb1 = fig.colorbar(im,ax=ax,format=fmt, ticks=tickz)

ax.text(-0.75,0,'1',horizontalalignment='center',verticalalignment='center',fontsize=64)
ax.text(0.75,0,'8',horizontalalignment='center',verticalalignment='center',fontsize=64)
ax.text(-0.25,0,'3',horizontalalignment='center',verticalalignment='center',fontsize=64)
ax.text(0.25,0,'6',horizontalalignment='center',verticalalignment='center',fontsize=64)

plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
# plot the learned RC for four well potential system
data=traj_data

hist=plt.hist2d(data[:,0],data[:,1],bins=100)
hist_RC=plt.hist2d(data[:,0],data[:,1],bins=[hist[1],hist[2]],weights=traj_mean_rep[:,0])
plt.close()

# %%
fig, ax = plt.subplots(figsize=(15,10))

RC=np.divide(hist_RC[0],hist[0])

im=ax.contourf(RC.T, extent=[hist_RC[1][0],hist_RC[1][-1],hist_RC[2][0],hist_RC[2][-1]],levels=10,
                    cmap=plt.cm.jet)
cb1 = fig.colorbar(im,ax=ax)
cb1.set_label('RC')

plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
# Out:
# <ipython-input-34-8ee287c41eee>:3: RuntimeWarning: invalid value encountered in true_divide
#   RC=np.divide(hist_RC[0],hist[0])
